# %% [markdown]
# 23070521135 - Sharvayu Zade

# %%
pip install numpy pandas matplotlib scikit-learn
# Out:
# Requirement already satisfied: numpy in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (3.10.8)
# Requirement already satisfied: scikit-learn in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.5.0 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.1.1 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in e:\Sharvayu data\Malware\Symbiosis Nagpur SIT\7th SEM\DL LAB\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
x = np.array([100,150,200,250,300])
y = np.array([20,25,30,35,40])
x_mean = np.mean(x)
y_mean = np.mean(y)
print("x mean:",x_mean)
print("y mean:",y_mean)
# Out:
# x mean: 200.0
# y mean: 30.0

# %%
b1 = np.sum((x-x_mean)*(y-y_mean))/np.sum((x-x_mean)**2)
print("slope b1:",b1)
b0=y_mean-b1*x_mean
print("intercept b0:",b0)
# Out:
# slope b1: 0.1
# intercept b0: 10.0

# %%
print("Equation of line: y = ",b1,"x + ",b0)
# Out:
# Equation of line: y =  0.1 x +  10.0

# %%
y_pred = b1*x+b0
print("Predicted values:",y_pred)
# Out:
# Predicted values: [20. 25. 30. 35. 40.]

# %%
mae = mean_absolute_error(y,y_pred)
mse = mean_squared_error(y,y_pred)
rmse = np.sqrt(mse)
print("MAE:",mae)
print("MSE:",mse)
print("RMSE:",rmse)
# Out:
# MAE: 0.0
# MSE: 0.0
# RMSE: 0.0

# %%
import matplotlib.pyplot as plt
plt.plot(x,y,'o',label='Actual values')
plt.plot(x,y_pred,label='Predicted values')
